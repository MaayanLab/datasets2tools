# %% [markdown]
# # Datasets2Tools API Manual
# **Denis Torre**
#
# *September 20, 2017*
#
# ## 1. Overview
# This notebook explains how to extract data from the Datasets2Tools API using Python.  The notebook can be downloaded at the following GitHub page: [`https://github.com/denis-torre/datasets2tools/tree/master/api`](https://github.com/denis-torre/datasets2tools/tree/master/api "title" target="_blank").
#
# ##### Basics
# - The Datasets2Tools search API can be accessed at the following URL: [`http://amp.pharm.mssm.edu/datasets2tools-dev/api/search`](http://amp.pharm.mssm.edu/datasets2tools-dev/api/search).
# - Searches are refined by adding several parameters, which are explained in more detail below.
# - The API returns a list of JSON objects containing information about the search results.
#
# ##### Object Types
# The Datasets2Tools API can be used to search three types of objects:
# - **Canned Analyses** ([`http://amp.pharm.mssm.edu/datasets2tools-dev/api/search?object_type=canned_analysis`](http://amp.pharm.mssm.edu/datasets2tools-dev/api/search?object_type=canned_analysis))
# - **Datasets** ([`http://amp.pharm.mssm.edu/datasets2tools-dev/api/search?object_type=dataset`](http://amp.pharm.mssm.edu/datasets2tools-dev/api/search?object_type=dataset))
# - **Tools** ([`http://amp.pharm.mssm.edu/datasets2tools-dev/api/search?object_type=tool`](http://amp.pharm.mssm.edu/datasets2tools-dev/api/search?object_type=tool))
#
# More detailed explanation on searching these objects is available below.
#
# ##### Demo
# Here is an example of search results for the analyses endpoint.

# %%
# Import modules
import json
import requests
import pandas as pd

# Get API URL
url = 'http://amp.pharm.mssm.edu/datasets2tools-dev/api/search'

# Search 5 analyses
data = {
    'object_type': 'canned_analysis',
    'page_size': 5
}

# Get response
response = requests.post(url, params=data)

# Read response
results = json.loads(response.text)

# Convert to dataframe
results_dataframe = pd.DataFrame(results)
results_dataframe
# Out:
#   canned_analysis_accession  \
# 0               DCA00000024
# 1               DCA00000025
# 2               DCA00000026
# 3               DCA00000027
# 4               DCA00000028
#
#                          canned_analysis_description  \
# 0  Highly interactive web-based heatmap visualiza...
# 1  Highly interactive web-based heatmap visualiza...
# 2  Highly interactive web-based heatmap visualiza...
# 3  Highly interactive web-based heatmap visualiza...
# 4  Highly interactive web-based heatmap visualiza...
#
#                          canned_analysis_preview_url  \
# 0  https://github.com/denis-torre/images/blob/mas...
# 1  https://github.com/denis-torre/images/blob/mas...
# 2  https://github.com/denis-torre/images/blob/mas...
# 3  https://github.com/denis-torre/images/blob/mas...
# 4  https://github.com/denis-torre/images/blob/mas...
#
#                                canned_analysis_title  \
# 0  Interactive heatmap visualization of RNA-seq d...
# 1  Interactive heatmap visualization of RNA-seq d...
# 2  Interactive heatmap visualization of RNA-seq d...
# 3  Interactive heatmap visualization of RNA-seq d...
# 4  Interactive heatmap visualization of RNA-seq d...
#
#                                  canned_analysis_url  contribution_fk  \
# 0  http://amp.pharm.mssm.edu/datasets2tools/analy...                5
# 1  http://amp.pharm.mssm.edu/datasets2tools/analy...                5
# 2  http://amp.pharm.mssm.edu/datasets2tools/analy...                5
# 3  http://amp.pharm.mssm.edu/datasets2tools/analy...                5
# 4  http://amp.pharm.mssm.edu/datasets2tools/analy...                5
#
#   dataset_accession                                dataset_description  \
# 0          GSE16256  The human embryonic stem cells (hESCs) are a u...
# 1          GSE17312  The NIH Roadmap Epigenomics Mapping Consortium...
# 2          GSE18927  The NIH Roadmap Epigenomics Mapping Consortium...
# 3          GSE22959  Deep Sequencing of protein-coding and non-prot...
# 4          GSE24565  This data was generated by ENCODE. If you have...
#
#                                  dataset_landing_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 2  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 3  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 4  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
#
#                                        dataset_title   ...    repository_fk  \
# 0     UCSD Human Reference Epigenome Mapping Project   ...                1
# 1       BI Human Reference Epigenome Mapping Project   ...                1
# 2  University of Washington Human Reference Epige...   ...                1
# 3  Sequencing of the non-ribosomal transcriptome ...   ...                1
# 4   Small RNA-seq from ENCODE/Cold Spring Harbor Lab   ...                1
#
#              repository_homepage_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/
# 1  https://www.ncbi.nlm.nih.gov/geo/
# 2  https://www.ncbi.nlm.nih.gov/geo/
# 3  https://www.ncbi.nlm.nih.gov/geo/
# 4  https://www.ncbi.nlm.nih.gov/geo/
#
#                                  repository_icon_url          repository_name  \
# 0  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 1  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 2  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 3  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 4  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
#
#   tool_accession                                   tool_description  \
# 0    DCT00010052  ARCHS4 provides access to gene counts from HiS...
# 1    DCT00010052  ARCHS4 provides access to gene counts from HiS...
# 2    DCT00010052  ARCHS4 provides access to gene counts from HiS...
# 3    DCT00010052  ARCHS4 provides access to gene counts from HiS...
# 4    DCT00010052  ARCHS4 provides access to gene counts from HiS...
#
#                    tool_homepage_url  \
# 0  http://amp.pharm.mssm.edu/archs4/
# 1  http://amp.pharm.mssm.edu/archs4/
# 2  http://amp.pharm.mssm.edu/archs4/
# 3  http://amp.pharm.mssm.edu/archs4/
# 4  http://amp.pharm.mssm.edu/archs4/
#
#                                        tool_icon_url tool_name username
# 0  http://labs.icahn.mssm.edu/maayanlab/wp-conten...    ARCHS4    denis
# 1  http://labs.icahn.mssm.edu/maayanlab/wp-conten...    ARCHS4    denis
# 2  http://labs.icahn.mssm.edu/maayanlab/wp-conten...    ARCHS4    denis
# 3  http://labs.icahn.mssm.edu/maayanlab/wp-conten...    ARCHS4    denis
# 4  http://labs.icahn.mssm.edu/maayanlab/wp-conten...    ARCHS4    denis
#
# [5 rows x 26 columns]

# %% [markdown]
# ## 2. Search Examples
# For convenience, we define a function to search the API and return a pandas DataFrame.

# %%
# Import modules
import json
import requests
import pandas as pd

def search_datasets2tools(search_options):
    
    # Get API URL
    url = 'http://amp.pharm.mssm.edu/datasets2tools-dev/api/search'

    # Get response
    response = requests.post(url, params=search_options)

    try:
        # Read response
        results_dict = json.loads(response.text)

        # Convert to dataframe
        results_dataframe = pd.DataFrame(results_dict)
        
        return results_dataframe
        
    except:
        
        return 'Sorry, there has been an error.'

# %% [markdown]
# ### 2.1 Canned Analyses
# We can search canned analyses by text, dataset, tool, or metadata tags.
#
# ##### 2.1.1 By Text
# Search all canned analyses that contain the keyword *prostate cancer*.

# %%
results = search_datasets2tools({'object_type': 'canned_analysis',
                                 'q': 'prostate cancer'})
results.head()
# Out:
#   canned_analysis_accession  \
# 0               DCA00000060
# 1               DCA00000123
# 2               DCA00000139
# 3               DCA00000262
# 4               DCA00000448
#
#                          canned_analysis_description  \
# 0  Highly interactive web-based heatmap visualiza...
# 1  Highly interactive web-based heatmap visualiza...
# 2  Highly interactive web-based heatmap visualiza...
# 3  Highly interactive web-based heatmap visualiza...
# 4  Highly interactive web-based heatmap visualiza...
#
#                          canned_analysis_preview_url  \
# 0  https://github.com/denis-torre/images/blob/mas...
# 1  https://github.com/denis-torre/images/blob/mas...
# 2  https://github.com/denis-torre/images/blob/mas...
# 3  https://github.com/denis-torre/images/blob/mas...
# 4  https://github.com/denis-torre/images/blob/mas...
#
#                                canned_analysis_title  \
# 0  Interactive heatmap visualization of RNA-seq d...
# 1  Interactive heatmap visualization of RNA-seq d...
# 2  Interactive heatmap visualization of RNA-seq d...
# 3  Interactive heatmap visualization of RNA-seq d...
# 4  Interactive heatmap visualization of RNA-seq d...
#
#                                  canned_analysis_url  contribution_fk  \
# 0  http://amp.pharm.mssm.edu/datasets2tools/analy...                5
# 1  http://amp.pharm.mssm.edu/datasets2tools/analy...                5
# 2  http://amp.pharm.mssm.edu/datasets2tools/analy...                5
# 3  http://amp.pharm.mssm.edu/datasets2tools/analy...                5
# 4  http://amp.pharm.mssm.edu/datasets2tools/analy...                5
#
#   dataset_accession                                dataset_description  \
# 0          GSE35126  Prostate cancer is the most common cancer in m...
# 1          GSE39509  We used RNA-seq to compare the expression prof...
# 2          GSE40050  The androgen receptor (AR) is a ligand-inducib...
# 3          GSE43986  Prostate glands predominantly exhibit androgen...
# 4          GSE48403  Androgen ablation therapy (AAT) is standard tr...
#
#                                  dataset_landing_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 2  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 3  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 4  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
#
#                                        dataset_title   ...    repository_fk  \
# 0  Effects of Cardiac Glycosides on RNA Expressio...   ...                1
# 1  Lineage analysis of basal epithelial cells rev...   ...                1
# 2  Persistent androgen receptor-mediated transcri...   ...                1
# 3  The Estrogen receptor alpha regulated NEAT1 lo...   ...                1
# 4  The Wnt/-catenin-signaling pathway is modulate...   ...                1
#
#              repository_homepage_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/
# 1  https://www.ncbi.nlm.nih.gov/geo/
# 2  https://www.ncbi.nlm.nih.gov/geo/
# 3  https://www.ncbi.nlm.nih.gov/geo/
# 4  https://www.ncbi.nlm.nih.gov/geo/
#
#                                  repository_icon_url          repository_name  \
# 0  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 1  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 2  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 3  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 4  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
#
#   tool_accession                                   tool_description  \
# 0    DCT00010052  ARCHS4 provides access to gene counts from HiS...
# 1    DCT00010052  ARCHS4 provides access to gene counts from HiS...
# 2    DCT00010052  ARCHS4 provides access to gene counts from HiS...
# 3    DCT00010052  ARCHS4 provides access to gene counts from HiS...
# 4    DCT00010052  ARCHS4 provides access to gene counts from HiS...
#
#                    tool_homepage_url  \
# 0  http://amp.pharm.mssm.edu/archs4/
# 1  http://amp.pharm.mssm.edu/archs4/
# 2  http://amp.pharm.mssm.edu/archs4/
# 3  http://amp.pharm.mssm.edu/archs4/
# 4  http://amp.pharm.mssm.edu/archs4/
#
#                                        tool_icon_url tool_name username
# 0  http://labs.icahn.mssm.edu/maayanlab/wp-conten...    ARCHS4    denis
# 1  http://labs.icahn.mssm.edu/maayanlab/wp-conten...    ARCHS4    denis
# 2  http://labs.icahn.mssm.edu/maayanlab/wp-conten...    ARCHS4    denis
# 3  http://labs.icahn.mssm.edu/maayanlab/wp-conten...    ARCHS4    denis
# 4  http://labs.icahn.mssm.edu/maayanlab/wp-conten...    ARCHS4    denis
#
# [5 rows x 26 columns]

# %% [markdown]
# ##### 2.1.2 By Dataset
# Search all canned analyses associated to GEO dataset GSE775.

# %%
results = search_datasets2tools({'object_type': 'canned_analysis',
                                 'dataset_accession': 'GSE775'})
results.head()

# %% [markdown]
# ##### 2.1.3 By Tool
# Search all canned analyses generated by Enrichr.

# %%
results = search_datasets2tools({'object_type': 'canned_analysis',
                                 'tool_name': 'Enrichr'})
results.head()
# Out:
#   canned_analysis_accession  \
# 0               DCA00000002
# 1               DCA00000003
# 2               DCA00000004
# 3               DCA00000005
# 4               DCA00059407
#
#                          canned_analysis_description  \
# 0  An enrichment analysis was performed on the to...
# 1  An enrichment analysis was performed on the to...
# 2  An enrichment analysis was performed on the to...
# 3  An enrichment analysis was performed on the to...
# 4  An enrichment analysis was performed on the to...
#
#                          canned_analysis_preview_url  \
# 0  https://raw.githubusercontent.com/denis-torre/...
# 1  https://raw.githubusercontent.com/denis-torre/...
# 2  https://raw.githubusercontent.com/denis-torre/...
# 3  https://raw.githubusercontent.com/denis-torre/...
# 4  https://raw.githubusercontent.com/denis-torre/...
#
#                                canned_analysis_title  \
# 0  Enrichment analysis of genes downregulated in ...
# 1  Enrichment analysis of genes upregulated in ac...
# 2  Enrichment analysis of genes downregulated in ...
# 3  Enrichment analysis of genes upregulated in ac...
# 4  Enrichment analysis of genes downregulated in ...
#
#                                  canned_analysis_url  contribution_fk  \
# 0  http://amp.pharm.mssm.edu/Enrichr/enrich?datas...                2
# 1  http://amp.pharm.mssm.edu/Enrichr/enrich?datas...                2
# 2  http://amp.pharm.mssm.edu/Enrichr/enrich?datas...                2
# 3  http://amp.pharm.mssm.edu/Enrichr/enrich?datas...                2
# 4  http://amp.pharm.mssm.edu/Enrichr/enrich?datas...               17
#
#   dataset_accession                                dataset_description  \
# 0            GSE775  Temporal analysis of acute myocardial infarcti...
# 1            GSE775  Temporal analysis of acute myocardial infarcti...
# 2            GSE775  Temporal analysis of acute myocardial infarcti...
# 3            GSE775  Temporal analysis of acute myocardial infarcti...
# 4            GSE775  Temporal analysis of acute myocardial infarcti...
#
#                                  dataset_landing_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 2  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 3  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 4  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
#
#                        dataset_title   ...    repository_fk  \
# 0  Myocardial infarction time course   ...                1
# 1  Myocardial infarction time course   ...                1
# 2  Myocardial infarction time course   ...                1
# 3  Myocardial infarction time course   ...                1
# 4  Myocardial infarction time course   ...                1
#
#              repository_homepage_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/
# 1  https://www.ncbi.nlm.nih.gov/geo/
# 2  https://www.ncbi.nlm.nih.gov/geo/
# 3  https://www.ncbi.nlm.nih.gov/geo/
# 4  https://www.ncbi.nlm.nih.gov/geo/
#
#                                  repository_icon_url          repository_name  \
# 0  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 1  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 2  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 3  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 4  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
#
#   tool_accession                                   tool_description  \
# 0    DCT00004702  A comprehensive gene set enrichment analysis w...
# 1    DCT00004702  A comprehensive gene set enrichment analysis w...
# 2    DCT00004702  A comprehensive gene set enrichment analysis w...
# 3    DCT00004702  A comprehensive gene set enrichment analysis w...
# 4    DCT00004702  A comprehensive gene set enrichment analysis w...
#
#                    tool_homepage_url  \
# 0  http://amp.pharm.mssm.edu/Enrichr
# 1  http://amp.pharm.mssm.edu/Enrichr
# 2  http://amp.pharm.mssm.edu/Enrichr
# 3  http://amp.pharm.mssm.edu/Enrichr
# 4  http://amp.pharm.mssm.edu/Enrichr
#
#                                        tool_icon_url tool_name username
# 0  http://amp.pharm.mssm.edu/Enrichr/images/enric...   Enrichr    denis
# 1  http://amp.pharm.mssm.edu/Enrichr/images/enric...   Enrichr    denis
# 2  http://amp.pharm.mssm.edu/Enrichr/images/enric...   Enrichr    denis
# 3  http://amp.pharm.mssm.edu/Enrichr/images/enric...   Enrichr    denis
# 4  http://amp.pharm.mssm.edu/Enrichr/images/enric...   Enrichr    denis
#
# [5 rows x 26 columns]

# %% [markdown]
# ##### 2.1.4 By Metadata
# Search all canned analyses with the *colon cancer* disease name.  Full list of available search options is available [here](http://www.google.com).

# %%
results = search_datasets2tools({'object_type': 'canned_analysis',
                                 'disease_name': 'colon cancer'})
results.head()
# Out:
#   canned_analysis_accession  \
# 0               DCA00032919
# 1               DCA00032920
# 2               DCA00033223
# 3               DCA00033224
# 4               DCA00033763
#
#                          canned_analysis_description  \
# 0  The analysis explores the gene interaction net...
# 1  The analysis explores the gene interaction net...
# 2  The analysis explores the gene interaction net...
# 3  The analysis explores the gene interaction net...
# 4  The analysis explores the gene interaction net...
#
#                          canned_analysis_preview_url  \
# 0  https://raw.githubusercontent.com/denis-torre/...
# 1  https://raw.githubusercontent.com/denis-torre/...
# 2  https://raw.githubusercontent.com/denis-torre/...
# 3  https://raw.githubusercontent.com/denis-torre/...
# 4  https://raw.githubusercontent.com/denis-torre/...
#
#                                canned_analysis_title  \
# 0  Interaction network and enrichment analysis of...
# 1  Interaction network and enrichment analysis of...
# 2  Interaction network and enrichment analysis of...
# 3  Interaction network and enrichment analysis of...
# 4  Interaction network and enrichment analysis of...
#
#                                  canned_analysis_url  contribution_fk  \
# 0  http://genemania.org/#/search/mouse/Lgals6|Guc...               13
# 1  http://genemania.org/#/search/mouse/Slpi|Gcnt2...               13
# 2  http://genemania.org/#/search/human/RPS4Y1|NDR...               13
# 3  http://genemania.org/#/search/human/FOS|SH3KBP...               13
# 4  http://genemania.org/#/search/human/RPS26|RPL1...               13
#
#   dataset_accession                                dataset_description  \
# 0           GSE2178  Expression profiles of different mouse tissue ...
# 1           GSE2178  Expression profiles of different mouse tissue ...
# 2           GSE4107  Analysis of normal-appearing colonic mucosa of...
# 3           GSE4107  Analysis of normal-appearing colonic mucosa of...
# 4          GSE34299  Analysis of HT29 and Colo205 parental colorect...
#
#                                  dataset_landing_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 2  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 3  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 4  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
#
#                                        dataset_title   ...    repository_fk  \
# 0                      Mouse Expression DB 2001 CHMC   ...                1
# 1                      Mouse Expression DB 2001 CHMC   ...                1
# 2  Early onset colorectal cancer: normal-appearin...   ...                1
# 3  Early onset colorectal cancer: normal-appearin...   ...                1
# 4  Colon cancer cell lines with acquired resistan...   ...                1
#
#              repository_homepage_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/
# 1  https://www.ncbi.nlm.nih.gov/geo/
# 2  https://www.ncbi.nlm.nih.gov/geo/
# 3  https://www.ncbi.nlm.nih.gov/geo/
# 4  https://www.ncbi.nlm.nih.gov/geo/
#
#                                  repository_icon_url          repository_name  \
# 0  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 1  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 2  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 3  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 4  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
#
#   tool_accession tool_description  tool_homepage_url          tool_icon_url  \
# 0    DCT00010073             None                     static/icons/tool.png
# 1    DCT00010073             None                     static/icons/tool.png
# 2    DCT00010073             None                     static/icons/tool.png
# 3    DCT00010073             None                     static/icons/tool.png
# 4    DCT00010073             None                     static/icons/tool.png
#
#    tool_name username
# 0  GeneMANIA    denis
# 1  GeneMANIA    denis
# 2  GeneMANIA    denis
# 3  GeneMANIA    denis
# 4  GeneMANIA    denis
#
# [5 rows x 26 columns]

# %% [markdown]
# ##### 2.1.5 Combined Search
# Search all analyses generated by Enrichr on dataset GSE31106, where the geneset is upregulated.

# %%
results = search_datasets2tools({'object_type': 'canned_analysis',
                                 'tool_name': 'Enrichr',
                                 'dataset_accession': 'GSE31106',
                                 'geneset': 'upregulated'})
results.head()
# Out:
#   canned_analysis_accession  \
# 0               DCA00059528
#
#                          canned_analysis_description  \
# 0  An enrichment analysis was performed on the to...
#
#                          canned_analysis_preview_url  \
# 0  https://raw.githubusercontent.com/denis-torre/...
#
#                                canned_analysis_title  \
# 0  Enrichment analysis of genes upregulated in co...
#
#                                  canned_analysis_url  contribution_fk  \
# 0  http://amp.pharm.mssm.edu/Enrichr/enrich?datas...               17
#
#   dataset_accession                                dataset_description  \
# 0          GSE31106  Temporal analysis of colon from AOM/DSS-induce...
#
#                                  dataset_landing_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
#
#                                        dataset_title   ...    repository_fk  \
# 0  Azoxymethane/dextran sulfate sodium-induced ul...   ...                1
#
#              repository_homepage_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/
#
#                                  repository_icon_url          repository_name  \
# 0  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
#
#   tool_accession                                   tool_description  \
# 0    DCT00004702  A comprehensive gene set enrichment analysis w...
#
#                    tool_homepage_url  \
# 0  http://amp.pharm.mssm.edu/Enrichr
#
#                                        tool_icon_url tool_name username
# 0  http://amp.pharm.mssm.edu/Enrichr/images/enric...   Enrichr    denis
#
# [1 rows x 26 columns]

# %% [markdown]
# ## 2.2 Datasets
# We can search datasets by accession, text-based search, names of tools which have analyzed them, accessions of canned analyses generated using them.
#
# ##### 2.2.1 By Accession
# Search dataset GSE775.

# %%
results = search_datasets2tools({'object_type': 'dataset',
                                 'dataset_accession': 'GSE775'})
results.head()
# Out:
#    analyses dataset_accession  \
# 0        42            GSE775
#
#                                  dataset_description  \
# 0  Temporal analysis of acute myocardial infarcti...
#
#                                  dataset_landing_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
#
#                        dataset_title     id internal_dataset_accession  \
# 0  Myocardial infarction time course  49384                DDS00049384
#
#                                       keywords  repository_fk  \
# 0  [ami, artery, infarction, left, myocardial]              1
#
#              repository_homepage_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/
#
#                                  repository_icon_url          repository_name
# 0  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus

# %% [markdown]
# ##### 2.2.2 By Text
# Search all datasets which contain the keyword *asthma*.

# %%
results = search_datasets2tools({'object_type': 'dataset',
                                 'q': 'asthma'})
results.head()
# Out:
#    analyses dataset_accession  \
# 0         1          GSE45975
# 1         1          GSE52742
# 2         1          GSE52778
# 3         1          GSE58434
# 4         1          GSE61141
#
#                                  dataset_description  \
# 0  Through their functional diversification, CD4+...
# 1  In this study we present the first genome-wide...
# 2  Rationale: Asthma is a chronic inflammatory ai...
# 3  Rationale: Asthma is a chronic inflammatory ai...
# 4  We report the application of RNA sequencing te...
#
#                                  dataset_landing_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 2  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 3  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 4  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
#
#                                        dataset_title    id  \
# 0  Bach2 represses effector programmes to stabili...   306
# 1  Genome-wide expression profiling of B Lymphocy...   603
# 2  Human Airway Smooth Muscle Transcriptome Chang...   605
# 3  Fatal Asthma vs. Control Human Airway Smooth M...  1016
# 4  Phenotypic responses of differentiated asthmat...  1242
#
#   internal_dataset_accession  \
# 0                DDS00000306
# 1                DDS00000603
# 2                DDS00000605
# 3                DDS00001016
# 4                DDS00001242
#
#                                             keywords  repository_fk  \
# 0               [bach, effector, lineages, th, treg]              1
# 1  [allergic, allergy, asthmain, genomewide, vali...              1
# 2          [airway, asthma, hasm, smooth, treatment]              1
# 3            [asm, asthma, children, fatal, vitamin]              1
# 4  [airway, asthma, epithelial, exacerbation, rhi...              1
#
#              repository_homepage_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/
# 1  https://www.ncbi.nlm.nih.gov/geo/
# 2  https://www.ncbi.nlm.nih.gov/geo/
# 3  https://www.ncbi.nlm.nih.gov/geo/
# 4  https://www.ncbi.nlm.nih.gov/geo/
#
#                                  repository_icon_url          repository_name
# 0  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 1  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 2  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 3  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 4  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus

# %% [markdown]
# ##### 2.2.3 By Tool
# Search all datasets which have been analyzed by Enrichr.

# %%
results = search_datasets2tools({'object_type': 'dataset',
                                 'tool_name': 'Enrichr'})
results.head()
# Out:
#    analyses dataset_accession  \
# 0        42            GSE775
# 1        14            GSE833
# 2         7           GSE4492
# 3         7          GSE47472
# 4         7          GSE50892
#
#                                  dataset_description  \
# 0  Temporal analysis of acute myocardial infarcti...
# 1  Identification of amyotrophic lateral sclerosi...
# 2  This SuperSeries is composed of the SubSeries ...
# 3  The aim of this study was to assess the gene e...
# 4  Glomerular abnormalities have been demonstrate...
#
#                                  dataset_landing_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 2  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 3  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 4  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
#
#                                        dataset_title     id  \
# 0                  Myocardial infarction time course  49384
# 1  Amyotrophic lateral sclerosis (Lou Gehrig's Di...  49405
# 2  Transcriptional reprogramming during reloading...  49406
# 3  Differential gene expression in the proximal n...  49407
# 4  Expression data from kidney biopsies of liver ...  49408
#
#   internal_dataset_accession  \
# 0                DDS00049384
# 1                DDS00049405
# 2                DDS00049406
# 3                DDS00049407
# 4                DDS00049408
#
#                                             keywords  repository_fk  \
# 0        [ami, artery, infarction, left, myocardial]              1
# 1    [als, amyotrophic, gehrigs, lateral, sclerosis]              1
# 2    [atrophied, musclethis, rat, reloading, soleus]              1
# 3       [aaas, abdominal, aneurysmthe, aortic, neck]              1
# 4  [abnormalities, biopsies, glomerular, kidney, ...              1
#
#              repository_homepage_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/
# 1  https://www.ncbi.nlm.nih.gov/geo/
# 2  https://www.ncbi.nlm.nih.gov/geo/
# 3  https://www.ncbi.nlm.nih.gov/geo/
# 4  https://www.ncbi.nlm.nih.gov/geo/
#
#                                  repository_icon_url          repository_name
# 0  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 1  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 2  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 3  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus
# 4  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus

# %% [markdown]
# ##### 2.3.4 By Canned Analysis
# Search all datasets which have been used to generate canned analysis DCA00000002.

# %%
results = search_datasets2tools({'object_type': 'dataset',
                                 'canned_analysis_accession': 'DCA00000002'})
results.head()
# Out:
#    analyses dataset_accession  \
# 0        42            GSE775
#
#                                  dataset_description  \
# 0  Temporal analysis of acute myocardial infarcti...
#
#                                  dataset_landing_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
#
#                        dataset_title     id internal_dataset_accession  \
# 0  Myocardial infarction time course  49384                DDS00049384
#
#                                       keywords  repository_fk  \
# 0  [ami, artery, infarction, left, myocardial]              1
#
#              repository_homepage_url  \
# 0  https://www.ncbi.nlm.nih.gov/geo/
#
#                                  repository_icon_url          repository_name
# 0  https://www.ncbi.nlm.nih.gov/geo/img/geo_main.gif  Gene Expression Omnibus

# %% [markdown]
# ### 2.3 Tools
# We can search tools by name, text-based search, accessions of analyzed datasets, accessions of canned analyses generated using them.
#
# ##### 2.3.1 By Name
# Search ARCHS4.

# %%
results = search_datasets2tools({'object_type': 'tool',
                                 'tool_name': 'ARCHS4'})
results.head()

# %% [markdown]
# ##### 2.3.2 By Text
# Search all tools which contain the keyword *enrichment*.

# %%
results = search_datasets2tools({'object_type': 'tool',
                                 'q': 'enrichment'})
results.head()

# %% [markdown]
# ##### 2.3.3 By Dataset
# Search all tools which have analyzed GEO dataset GSE775.

# %%
results = search_datasets2tools({'object_type': 'tool',
                                 'dataset_accession': 'GSE775'})
results.head()

# %% [markdown]
# ##### 2.3.4 By Canned Analysis
# Search all tools which have been used to generate canned analysis DCA00000002.

# %%
results = search_datasets2tools({'object_type': 'tool',
                                 'canned_analysis_accession': 'DCA00000002'})
results.head()
